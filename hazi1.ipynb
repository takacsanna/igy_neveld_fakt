# %% [markdown]
# <a href="https://colab.research.google.com/github/takacsanna/igy_neveld_fakt/blob/main/hazi1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. házi feladat

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from google.colab import drive
from PIL import Image

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Képek hozzáadása

# %%
maci = plt.imread('/content/drive/My Drive/Python kurzus/maci.jpg')
baba = plt.imread('/content/drive/My Drive/Python kurzus/baba.jpg')
gyumolcs = plt.imread('/content/drive/My Drive/Python kurzus/gyumolcs.jpg')

# %% [markdown]
# ##Zajgenerálás

# %%
szonyeg = np.random.randint(0,255,(300,300,3))

# %%
plt.imshow(szonyeg)

# %% [markdown]
# ##RGB-csatornák kipróbálása

# %%
plt.imshow(szonyeg[:,:,0], cmap='gray')

# %%
plt.imshow(szonyeg[:,:,1], cmap='gray')

# %%
plt.imshow(szonyeg[:,:,2], cmap='gray')

# %% [markdown]
# ##Megjelenítés egy plotban

# %%
f, axarr = plt.subplots(2,2)
axarr[0,0].imshow(maci)
axarr[0,1].imshow(gyumolcs)
axarr[1,0].imshow(baba)
axarr[1,1].imshow(szonyeg)

# %% [markdown]
# #Színátlagok kiszámítása

# %%
kepek = [maci, baba, gyumolcs, szonyeg]
for kep in range(4):
  for channel in range(3):
    print(kepek[kep][:,:,channel].mean())
# Out:
# 124.46576136837714
# 119.20421568627451
# 112.06190446391322
# 73.69295791487326
# 75.97982623943886
# 86.7478718316595
# 79.10603873132975
# 56.19019849428554
# 49.10746167684586
# 127.07174444444445
# 127.11473333333333
# 127.00734444444444

# %% [markdown]
# ##Transzformációk készítése

# %%
baba = Image.open('/content/drive/My Drive/Python kurzus/baba.jpg')

# %%
baba.transpose(Image.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=615x408 at 0x7F6A39AE4950>

# %%
baba.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=615x408 at 0x7F6A39B31510>

# %%
baba.transpose(Image.QUAD)
# Out:
# <PIL.Image.Image image mode=RGB size=615x408 at 0x7F6A39AA7990>

# %%
baba.thumbnail(size=(200,200))
baba
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x133 at 0x7F6A39B1EA50>
